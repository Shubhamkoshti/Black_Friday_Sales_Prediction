# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubhamkoshti/Black_Friday_Sales_Prediction/blob/main/Black_friday_sales_Shubham.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Black_Friday_Sales_Train.csv")

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17        10.0             A
# 1  1000001  P00248942      F  0-17        10.0             A
# 2  1000001  P00087842      F  0-17        10.0             A
# 3  1000001  P00085442      F  0-17        10.0             A
# 4  1000002  P00285442      M   55+        16.0             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# 3                          2             0.0                12.0
# 4                         4+             0.0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  4.969240e+05  496923.000000   496923.000000       496923.000000
# mean   1.002983e+06       8.083975        0.408665            5.297173
# std    1.713741e+03       6.523967        0.491588            3.750572
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001489e+06       2.000000        0.000000            1.000000
# 50%    1.003021e+06       7.000000        0.000000            5.000000
# 75%    1.004399e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       342510.000000       151835.000000  496923.000000
# mean             9.842238           12.663826    9330.825796
# std              5.087088            4.126385    4980.595366
# min              2.000000            3.000000     185.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 496924 entries, 0 to 496923
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     496924 non-null  int64
#  1   Product_ID                  496924 non-null  object
#  2   Gender                      496924 non-null  object
#  3   Age                         496924 non-null  object
#  4   Occupation                  496923 non-null  float64
#  5   City_Category               496923 non-null  object
#  6   Stay_In_Current_City_Years  496923 non-null  object
#  7   Marital_Status              496923 non-null  float64
#  8   Product_Category_1          496923 non-null  float64
#  9   Product_Category_2          342510 non-null  float64
#  10  Product_Category_3          151835 non-null  float64
#  11  Purchase                    496923 non-null  float64
# dtypes: float64(6), int64(1), object(5)
# ...

# %%
df.shape
# Out:
# (496924, 12)

# %%
df.nunique()
# Out:
# User_ID                        5891
# Product_ID                     3612
# Gender                            2
# Age                               7
# Occupation                       21
# City_Category                     3
# Stay_In_Current_City_Years        5
# Marital_Status                    2
# Product_Category_1               18
# Product_Category_2               17
# Product_Category_3               15
# Purchase                      17816
# dtype: int64

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         1
# City_Category                      1
# Stay_In_Current_City_Years         1
# Marital_Status                     1
# Product_Category_1                 1
# Product_Category_2            154414
# Product_Category_3            345089
# Purchase                           1
# dtype: int64

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 496919    False
# 496920    False
# 496921    False
# 496922    False
# 496923    False
# Length: 496924, dtype: bool

# %%
df.tail()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 496919  1004485  P00048742      M  26-35         4.0             C
# 496920  1004485  P00250242      M  26-35         4.0             C
# 496921  1004486  P00242242      M  36-45         8.0             C
# 496922  1004486  P00204242      M  36-45         8.0             C
# 496923  1004487  P00009342      M  26-35         NaN           NaN
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 496919                          1             0.0                 5.0
# 496920                          1             0.0                 5.0
# 496921                          1             0.0                 5.0
# 496922                          1             0.0                 6.0
# 496923                        NaN             NaN                 NaN
#
#         Product_Category_2  Product_Category_3  Purchase
# 496919                 NaN                 NaN    5236.0
# ...
